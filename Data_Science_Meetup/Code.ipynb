# %% [markdown]
# ### Data Science Machine Learning Coding Project Pasadena, Los Angeles
# #### Attendent: Kai-yu Chen

# %% [markdown]
# ## 1. Note for presentation

# %% [markdown]
# Data Science:
#  - computer science
#  - math
#  - domain knowledge***
#  - communication
#
# *Domain knowledge is the most important of all. That's where you can fit your specialization in the data science field.
#
# Boosting of data science:
# - big data
# - cloud is cheap
# - computer power
#
# *unstructured data (raw data) grows exponentially faster than structured data(labeled).
# *image - openCV
# *deep learning - tensorflow
# *R - good at time series data processing, more pupular in finance and healthcare.
#
# Top popular models:
#  - logistic regression
#  - decision tree
#  - random forest
#  - neural network
#  - baysian inference
#  - ensemble methods
#
# popular package:
#  - pandas
#  - matplotlib
#  - numpy
#  - seaborn
#  - scikit-learn
#
# **evaluate models:
# classifications:
#  - precision
#  - recall
#
# regression:
#  - RMSE
#  - Adjusted R-squared

# %% [markdown]
# ### 2. Code
# - if only choose one feature, what feature would you choose?(huh???)

# %% [markdown]
# ### 1) Import Library

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from scipy import stats

# %%
data = pd.read_csv("csvFiles/kc_house_data.csv")
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.shape
# Out:
# (21613, 21)

# %%
# understand data features
pd.read_csv?

# %% [markdown]
# ### 2) Data Understanding

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
# id               21613 non-null int64
# date             21613 non-null object
# price            21613 non-null float64
# bedrooms         21613 non-null int64
# bathrooms        21613 non-null float64
# sqft_living      21613 non-null int64
# sqft_lot         21613 non-null int64
# floors           21613 non-null float64
# waterfront       21613 non-null int64
# view             21613 non-null int64
# condition        21613 non-null int64
# grade            21613 non-null int64
# sqft_above       21613 non-null int64
# sqft_basement    21613 non-null int64
# yr_built         21613 non-null int64
# yr_renovated     21613 non-null int64
# zipcode          21613 non-null int64
# lat              21613 non-null float64
# long             21613 non-null float64
# sqft_living15    21613 non-null int64
# sqft_lot15       21613 non-null int64
# ...

# %%
data.isnull().sum()
# Out:
# id               0
# date             0
# price            0
# bedrooms         0
# bathrooms        0
# sqft_living      0
# sqft_lot         0
# floors           0
# waterfront       0
# view             0
# condition        0
# grade            0
# sqft_above       0
# sqft_basement    0
# yr_built         0
# yr_renovated     0
# zipcode          0
# lat              0
# long             0
# sqft_living15    0
# sqft_lot15       0
# dtype: int64

# %%
data.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
data.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
data.tail()
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view     ...      grade  \
# 21608         1530      1131     3.0           0     0     ...          8
# 21609         2310      5813     2.0           0     0     ...          8
# 21610         1020      1350     2.0           0     0     ...          7
# 21611         1600      2388     2.0           0     0     ...          8
# 21612         1020      1076     2.0           0     0     ...          7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# ...

# %%
# change time to datetime object#  
data['date'] = pd.to_datetime(data['date'])

# %%
data.head()
# Out:
#            id       date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520 2014-10-13  221900.0         3       1.00         1180
# 1  6414100192 2014-12-09  538000.0         3       2.25         2570
# 2  5631500400 2015-02-25  180000.0         2       1.00          770
# 3  2487200875 2014-12-09  604000.0         4       3.00         1960
# 4  1954400510 2015-02-18  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
print (data['date'][0])
print (data['date'][0].year)
print (data['date'][0].month)
print (data['date'][0].day)
# Out:
# 2014-10-13 00:00:00
# 2014
# 10
# 13

# %%
max(data['date']), min(data['date'])
# Out:
# (Timestamp('2015-05-27 00:00:00'), Timestamp('2014-05-02 00:00:00'))

# %% [markdown]
# #### Let's look at the price

# %%
plt.hist(data['price'])
# Out:
# (array([1.9021e+04, 2.1480e+03, 3.1600e+02, 9.0000e+01, 2.6000e+01,
#         4.0000e+00, 4.0000e+00, 1.0000e+00, 1.0000e+00, 2.0000e+00]),
#  array([  75000.,  837500., 1600000., 2362500., 3125000., 3887500.,
#         4650000., 5412500., 6175000., 6937500., 7700000.]),
#  <a list of 10 Patch objects>)

# %%
plt.hist(np.log(data['price']))
# Out:
# (array([6.300e+01, 5.330e+02, 3.977e+03, 7.183e+03, 6.345e+03, 2.541e+03,
#         7.330e+02, 1.930e+02, 3.800e+01, 7.000e+00]),
#  array([11.22524339, 11.68839214, 12.15154089, 12.61468964, 13.07783839,
#         13.54098714, 14.00413589, 14.46728464, 14.93043339, 15.39358214,
#         15.85673089]),
#  <a list of 10 Patch objects>)

# %%
# get distinct values in this column
data['bedrooms'].unique()
# Out:
# array([ 3,  2,  4,  5,  1,  6,  7,  0,  8,  9, 11, 10, 33])

# %%
# get how many of these distinct value
data['bedrooms'].nunique()
# Out:
# 13

# %%
data[data["bedrooms"]==0]
# Out:
#                id       date      price  bedrooms  bathrooms  sqft_living  \
# 875    6306400140 2014-06-12  1095000.0         0       0.00         3064
# 3119   3918400017 2015-02-05   380000.0         0       0.00         1470
# 3467   1453602309 2014-08-05   288000.0         0       1.50         1430
# 4868   6896300380 2014-10-02   228000.0         0       1.00          390
# 6994   2954400190 2014-06-24  1295650.0         0       0.00         4810
# 8477   2569500210 2014-11-17   339950.0         0       2.50         2290
# 8484   2310060040 2014-09-25   240000.0         0       2.50         1810
# 9773   3374500520 2015-04-29   355000.0         0       0.00         2460
# 9854   7849202190 2014-12-23   235000.0         0       0.00         1470
# 12653  7849202299 2015-02-18   320000.0         0       2.50         1490
# 14423  9543000205 2015-04-13   139950.0         0       0.00          844
# 18379  1222029077 2014-10-29   265000.0         0       0.75          384
# ...

# %%
data[data["bedrooms"]>=11]
# possibily a typo in bedrooms
# Out:
#                id       date     price  bedrooms  bathrooms  sqft_living  \
# 8757   1773100755 2014-08-21  520000.0        11       3.00         3000
# 15870  2402100895 2014-06-25  640000.0        33       1.75         1620
#
#        sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 8757       4960     2.0           0     0     ...          7        2400
# 15870      6000     1.0           0     0     ...          7        1040
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# 8757             600      1918          1999    98106  47.5560 -122.363
# 15870            580      1947             0    98103  47.6878 -122.331
#
#        sqft_living15  sqft_lot15
# 8757            1420        4960
# 15870           1330        4700
#
# [2 rows x 21 columns]

# %%
plt.scatter(data['sqft_living'], data['price'])

# %% [markdown]
# ### 3) Data Preparation

# %%
data.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
data.corr()
# Out:
#                      id     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             1.000000 -0.016762  0.001286   0.005160    -0.012258 -0.132109
# price         -0.016762  1.000000  0.308350   0.525138     0.702035  0.089661
# bedrooms       0.001286  0.308350  1.000000   0.515884     0.576671  0.031703
# bathrooms      0.005160  0.525138  0.515884   1.000000     0.754665  0.087740
# sqft_living   -0.012258  0.702035  0.576671   0.754665     1.000000  0.172826
# sqft_lot      -0.132109  0.089661  0.031703   0.087740     0.172826  1.000000
# floors         0.018525  0.256794  0.175429   0.500653     0.353949 -0.005201
# waterfront    -0.002721  0.266369 -0.006582   0.063744     0.103818  0.021604
# view           0.011592  0.397293  0.079532   0.187737     0.284611  0.074710
# condition     -0.023783  0.036362  0.028472  -0.124982    -0.058753 -0.008958
# grade          0.008130  0.667434  0.356967   0.664983     0.762704  0.113621
# ...

# %%
# calculate edge of the house
data['age_total'] = 2018-data['yr_built']

# %%
# does the house have new rennovation??
data['renovated'] = data['yr_renovated'].apply(lambda x: 1 if x > 0 else 0)

# %% [markdown]
# ### 4) Modeling

# %%
predict_house_price = stats.linregress(data['sqft_living'], data['price'])

# %%
predict_house_price
# Out:
# LinregressResult(slope=280.62356789744837, intercept=-43580.743094474194, rvalue=0.7020350546118002, pvalue=0.0, stderr=1.9363985519989138)

# %% [markdown]
# #### Deployment

# %%
def predict(x):
    return predict_house_price.slope * x + predict_house_price.intercept

# %%
predict(4000)
# Out:
# 1078913.5284953192

# %% [markdown]
# ## Last: Resources

# %% [markdown]
# - Kaggle
# - Sci-kit cheat sheet:
#     http://scikit-learn.org/stable/tutorial/machine_learning_map/index.html
# - Quora Data Science Cheat Sheet:
#     https://www.quora.com/What-are-some-good-data-science-cheat-sheets
# - Articles:
#     - https://www.kdnuggets.com/2015/05/r-vs-python-data-science.html
#     - https://www.datacamp.com/community/tutorials/r-or-python-for-data-analysis
# - Books:
#     - naked Statistics
#     https://www.amazon.com/Naked-Statistics-Stripping-Dread-Data/dp/1480590185
#     - Python for data analysis
#     https://www.amazon.com/Python-Data-Analysis-Wrangling-IPython/dp/1449319793
#
# - online class:
#     https://www.commonlounge.com/
